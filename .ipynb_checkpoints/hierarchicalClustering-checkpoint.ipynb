# %%
# Libraries
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.metrics import silhouette_score
plt.style.use("seaborn")

# %%
# Create synthetic clusters
X, y = make_blobs(n_samples=10, centers=3, n_features=2, random_state=123)

# Plot
Z = linkage(X, 'complete')
plt.figure(figsize=(10, 8))
plt.title('Dendrogram', fontdict = {'fontsize' : 16})
plt.xlabel('Observation', fontdict = {'fontsize' : 14})
plt.ylabel('Distance', fontdict = {'fontsize' : 14})
plt.axhline(y=8, c='k', linestyle='--')
plt.axhline(y=5, c='k')
dendrogram(
    Z,
    leaf_font_size=16.,  # font size for the x axis labels
)
plt.show()

# %%
# Create synthetic clusters
X, y = make_blobs(n_samples=50, centers=2, n_features=2, random_state=123)

# Plot
plt.scatter(X[:,0], X[:,1], c=y, cmap='rainbow')
plt.title("True cluster labels")
plt.xlabel("x0")
plt.ylabel("x1")
plt.show()

#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123, test_size=0.25)

# %%
# Assign linkage
Z = linkage(X, 'complete')

plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
fcluster(Z, t=3, criterion='maxclust')
# Out:
# array([3, 1, 3, 3, 1, 2, 2, 3, 1, 3, 3, 1, 3, 3, 1, 1, 1, 1, 3, 3, 3, 3,
#        2, 2, 1, 1, 1, 1, 3, 1, 1, 1, 3, 1, 3, 1, 1, 1, 3, 3, 3, 3, 1, 1,
#        1, 1, 1, 3, 3, 1], dtype=int32)

# %%
# Plot
plt.scatter(X[:,0], X[:,1], c=fcluster(Z, t=3, criterion='maxclust'), cmap='rainbow')
plt.title("True cluster labels")
plt.xlabel("x0")
plt.ylabel("x1")
plt.show()

# %%
#silhouette_score(X, fcluster(Z, t=2, criterion='maxclust'))
def sil_scores(X, Z, ts):
    scores = []
    
    for k in ts:
        scores.append(silhouette_score(X, fcluster(Z, t=k, criterion='maxclust')))
    
    return scores

ts = [2,3,4,5,6]
scores = sil_scores(X, Z, ts)

for t, s in zip(ts, scores):
    print(f"With {t} clusters, the silhouette score is {s}")
# Out:
# With 2 clusters, the silhouette score is 0.8022134420580112
# With 3 clusters, the silhouette score is 0.574973064457792
# With 4 clusters, the silhouette score is 0.3468456934160835
# With 5 clusters, the silhouette score is 0.3387625660853402
# With 6 clusters, the silhouette score is 0.34918123054214123
